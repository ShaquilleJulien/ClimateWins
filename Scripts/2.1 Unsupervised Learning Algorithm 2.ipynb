# %%
#import libraries 
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import os
from mpl_toolkits import mplot3d
from plotly.offline import download_plotlyjs, init_notebook_mode
from plotly.offline import plot, iplot
import plotly.graph_objects as go
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage, cophenet
from scipy.spatial.distance import pdist

# %%
path = R'/Users/shaquillelee/Documents/Specialization '

# %%
reduced_df = pd.read_csv(os.path.join(path,'Datasets','PCA1998.csv'),index_col = 0)

# %%
reduced_df
# Out:
#          PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0   -7.432930 -2.393448  2.310335 -2.377409  1.961464  0.340771 -0.614123
# 1   -6.326829 -8.333777  1.616558 -4.638308  1.927428 -0.974521  0.586972
# 2   -5.435767 -6.909376  3.068086 -5.362126  1.448563 -2.567834  0.838423
# 3   -6.213143 -5.329330  3.564045 -6.992534  0.920426 -3.147630  1.440731
# 4   -6.776941 -5.569702  3.885756 -5.886646 -0.070722 -3.331782  2.576708
# ..        ...       ...       ...       ...       ...       ...       ...
# 360 -7.443351 -4.100556  6.112068 -3.916109  0.457897 -2.530488  2.520541
# 361 -7.321920 -1.583892  3.896439 -3.636112  1.477716 -0.205287  0.979646
# 362 -7.899792  1.901158  0.821525 -3.653803  4.179257  2.058262 -0.497092
# 363 -8.318879  2.164459  0.718654 -4.862668  5.702069  0.681428 -1.711997
# 364 -9.393955 -1.426869  0.394332 -3.301260  3.923460  1.754287 -1.660896
#
#          PCA8      PCA9     PCA10
# 0    0.571146  0.622623  1.939417
# 1   -0.190284  2.138872  0.442081
# 2   -1.074653  2.075630 -0.053158
# 3    0.006924  1.543598 -1.091081
# 4    0.158332 -0.547607  0.211862
# ..        ...       ...       ...
# 360  0.080315 -0.184291 -1.156080
# 361 -0.855081 -0.895343 -0.455031
# 362  0.068354  0.462713  1.231073
# 363 -0.621785  0.904469  1.971823
# 364  0.123648  3.020746 -1.368086
#
# [365 rows x 10 columns]

# %% [markdown]
# ## ReRunning Dendrogram on reduced data

# %%
#Single Method 
distance_single = linkage(reduced_df.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %%
#complete Method 
distance_single = linkage(reduced_df.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10']],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %%
#Average MEthod 
distance_single= linkage(reduced_df.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10']],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %%
#Ward Method 
distance_single = linkage(reduced_df.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9',
'PCA10']],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()
